# %%
path="/Volumes/my_catalog/my_schema/my_volume/my_project_ecommerce/bronze/customers_Final.csv"
customers_df=spark.read.format("csv").option("header","true").option("inferschema","true").load(path)
customers_df.display()
